# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data=sns.load_dataset('penguins')
sns.displot(data=penguins, x="flipper_length_mm", hue="species", col="species")

# %%
import matplotlib.pyplot as plt
f, axs = plt.subplots(1, 2, figsize=(8, 4), gridspec_kw=dict(width_ratios=[4, 3]))
sns.scatterplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species", ax=axs[0])
sns.histplot(data=penguins, x="species", hue="species", shrink=0.4, alpha=1, legend=True, ax=axs[1]) #shrink closese the gap between data
f.tight_layout()

# %%
# g = sns.FacetGrid(penguins)
g = sns.FacetGrid(penguins,col='species')

# %% [markdown]
# ### dataloading for fottbal vis

# %%
fotb=pd.read_csv('spi_matches.csv')

# %%
fotb.columns
# Out:
# Index(['season', 'date', 'league_id', 'league', 'team1', 'team2', 'spi1',
#        'spi2', 'prob1', 'prob2', 'probtie', 'proj_score1', 'proj_score2',
#        'importance1', 'importance2', 'score1', 'score2', 'xg1', 'xg2', 'nsxg1',
#        'nsxg2', 'adj_score1', 'adj_score2'],
#       dtype='object')

# %%
# fotb.isnull().sum()
len(fotb)
# len(fotb)
# Out:
# 65977

# %%
# np.unique(fotb.league)
# fotb.groupby(['']).mean()
# fotb.league=['English League One']
# fotb.league =='English League One'
# df.groupby('Courses')['Fee'].aggregate(['min','max'])
# fotb.groupby('league').first().head(2)
irs=sns.load_dataset('iris')
irs.head(5)
# sns.displot(data=fotb,x='score1',hue='league')
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
f,axs=plt.subplots(1,3,figsize=(12,4))
sns.scatterplot(data=irs, x="sepal_width", y="petal_length", hue="species", ax=axs[0])
sns.histplot(data=irs, x="species", hue="species", shrink=.4, alpha=.8, legend=False, ax=axs[1])
sns.histplot(data=irs, x="species", hue="species",kind='kde' ,shrink=.4, alpha=.8, legend=False, ax=axs[2])
# sns.distplot(data=irs, x="sepal_width",hue='species',multiple='stack')
# sns.kdeplot(data=irs, x="petal_length", hue="species", multiple="stack")
# sns.displot(data=irs, x="petal_length", hue="species", multiple="stack",kind='kde',ax=axs[0])

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)
sns.kdeplot(data=irs,x='petal_length',hue='species',multiple='stack',ax=ax1)
sns.jointplot(data=irs,x=irs['sepal_width'],y='petal_length', hue='species', ax=ax2)
# Out:
# C:\Users\erfan\AppData\Local\Temp\ipykernel_12060\3916973114.py:3: UserWarning: Ignoring `ax`; jointplot is a figure-level function.
#   sns.jointplot(data=irs,x=irs['sepal_width'],y='petal_length', hue='species', ax=ax2)

# %%
# Libraries
import pandas as pd

# read the data (on the web)
data = pd.read_csv('https://raw.githubusercontent.com/holtzy/The-Python-Graph-Gallery/master/static/data/gapminderData.csv')
# Check the first 2 rows

# %%
data.head()
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106

# %%
data1952['pop']/50000
# Out:
# 0       168.50666
# 12       25.65394
# 24      185.59050
# 36       84.64190
# 48      357.53912
#           ...
# 1644    524.93678
# 1656     20.61170
# 1668     99.27658
# 1680     53.44000
# 1692     61.61814
# Name: pop, Length: 142, dtype: float64

# %%
data['continent']=pd.Categorical(data['continent'])

# Set the figure size
plt.figure(figsize=(15, 7))

# Subset of the data for year 1952
data1952 = data[ data.year == 1952 ]

# Scatterplot
plt.scatter(
    x = data1952['lifeExp'], y = data1952['gdpPercap'], s=data1952['pop']/50000,c=data1952['continent'].cat.codes, cmap="Accent", alpha=0.7, edgecolors="grey", 
    linewidth=2);

# Add titles (main and on axis)
plt.yscale('log')
plt.xlabel("Life Expectancy")
plt.ylabel("GDP per Capita")
plt.title("Year 1952")
plt.ylim(0,50000)
plt.xlim(30, 75);
# Out:
# C:\Users\erfan\AppData\Local\Temp\ipykernel_17276\3138473887.py:19: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim(0,50000)

# %%
# irs['species'].replace({'setosa':'1', 'versicolor':'2','virginica':'3'}, inplace = True)
irs
# Out:
#      sepal_length  sepal_width  petal_length  petal_width species
# 0             5.1          3.5           1.4          0.2       1
# 1             4.9          3.0           1.4          0.2       1
# 2             4.7          3.2           1.3          0.2       1
# 3             4.6          3.1           1.5          0.2       1
# 4             5.0          3.6           1.4          0.2       1
# ..            ...          ...           ...          ...     ...
# 145           6.7          3.0           5.2          2.3       3
# 146           6.3          2.5           5.0          1.9       3
# 147           6.5          3.0           5.2          2.0       3
# 148           6.2          3.4           5.4          2.3       3
# 149           5.9          3.0           5.1          1.8       3
#
# [150 rows x 5 columns]

# %%
irs.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
irs=sns.load_dataset('iris')
# plt.scatter(
#     x = data1952['lifeExp'], y = data1952['gdpPercap'], s=data1952['pop']/50000,c=data1952['continent'].cat.codes, cmap="Accent", alpha=0.7, edgecolors="grey", 
#     linewidth=2);m
# plt.yscale('log')
# # plt.xscale('log')
# plt.xlabel("Life Expectancy")
# plt.ylabel("GDP per Capita")
# plt.title("Year 1952")
# plt.ylim(-100,20000)
# plt.xlim(25, 75);

g=sns.scatterplot(data=data1952,x='lifeExp',y='gdpPercap',s=data1952['pop']/50000 ,legend=False,alpha=0.7,
                     cmap="Accent",edgecolors="white",c=data1952['continent'].cat.codes)
# g=sns.scatterplot(data=irs,x='petal_length',y='petal_width',s=irs['petal_length']*50 ,legend=False,alpha=0.7,
#                         hue='species')
plt.yscale('log')
plt.ylim(-10, 20000)
plt.xlim(30,70)
# Out:
# C:\Users\erfan\AppData\Local\Temp\ipykernel_17276\4038182342.py:18: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim(-10, 20000)
# (30.0, 70.0)

# %%
# libraries & dataset
import seaborn as sns
import matplotlib.pyplot as plt
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) 
f,axs=plt.subplots(1,5,figsize=(15,5),sharex=False)
# sns.set(style="darkgrid")
df = sns.load_dataset('iris')
 
# density plot with shaded area with kdeplot 'shade' parameter
sns.scatterplot(df,x=df['sepal_width'],y='sepal_length',hue='species',ax=axs[0],)
sns.kdeplot(df,x='sepal_width',fill=True, color="skyblue",ax=axs[1])
sns.kdeplot(df['sepal_width'], bw_method=0.05, color='olive',ax=axs[2])
fig = sns.kdeplot(df['sepal_width'], shade=True, color="r",ax=axs[3])
fig = sns.kdeplot(df['sepal_length'], shade=True, color="b",ax=axs[3])
# Out:
# C:\Users\erfan\AppData\Local\Temp\ipykernel_12060\3279233050.py:13: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   fig = sns.kdeplot(df['sepal_width'], shade=True, color="r",ax=axs[3])
# C:\Users\erfan\AppData\Local\Temp\ipykernel_12060\3279233050.py:14: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   fig = sns.kdeplot(df['sepal_length'], shade=True, color="b",ax=axs[3])

# %%
# Out:
# 0.12.1
